# %% [markdown]
# # Post Training Analysis
#
# Here lies the analysis of our findings

# %%
import pandas as pd 
import numpy as nb
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
# bring the log file
file_path = "../../log.csv"

results = pd.read_csv(file_path)
results
# Out:
#                                     data variational  convolution
# 0         ../workfiles/light_BRCA_ds.pkl       False         True  \
# 1            ../workfiles/PPMI_genes.pkl       False         True
# 2         ../workfiles/light_BRCA_ds.pkl       False         True
# 3            ../workfiles/PPMI_genes.pkl       False         True
# 4         ../workfiles/light_BRCA_ds.pkl       False         True
# ..                                   ...         ...          ...
# 100       ../workfiles/light_BRCA_ds.pkl         NaN         True
# 101          ../workfiles/PPMI_genes.pkl         NaN         True
# 102  ../workfiles/PPMI_genes_PD_only.pkl         NaN         True
# 103       ../workfiles/light_BRCA_ds.pkl      VQ-VAE         True
# 104          ../workfiles/PPMI_genes.pkl      VQ-VAE         True
#
#      transformer  dropout  latent_dim  padding  kernel_size   hopkins
# 0          False      0.3          64        3            7  0.920001  \
# 1          False      0.3          64        3            7  0.967938
# 2          False      0.5          64        1            3  0.788441
# 3          False      0.5          64        1            3  0.798850
# 4          False      0.3          16        2            5  0.657913
# ..           ...      ...         ...      ...          ...       ...
# 100        False      0.1          16        2            5  0.730126
# 101        False      0.1          16        2            5  0.776597
# 102        False      0.1          16        2            5  0.795068
# 103        False      0.1         128        1            3  0.658982
# 104        False      0.1         128        1            3  0.683237
#
#           ari       nmi  silhouette        fm  homogeneity  completeness
# 0    0.101950  0.139962    0.265472  0.352087     0.155744      0.127085  \
# 1   -0.002566  0.003083    0.318965  0.428661     0.004613      0.002316
# 2    0.224102  0.269266    0.082414  0.452619     0.293811      0.248507
# 3    0.000748  0.007063    0.069840  0.381251     0.011548      0.005087
# 4    0.196644  0.281278    0.077490  0.421511     0.314359      0.254497
# ..        ...       ...         ...       ...          ...           ...
# 100  0.155617  0.248108    0.104178  0.410244     0.267848      0.231078
# 101 -0.013216  0.005614    0.144002  0.437029     0.008369      0.004224
# 102  0.024922  0.018060    0.219111  0.526523     0.036901      0.011956
# 103  0.159659  0.238715    0.064201  0.392837     0.267033      0.215828
# 104 -0.000133  0.007511    0.057945  0.364960     0.012561      0.005357
#
#      v_measure  num_layers  commitment_cost  embedding_dim  num_embeddings
# 0     0.139962         NaN              NaN            NaN             NaN
# 1     0.003083         NaN              NaN            NaN             NaN
# 2     0.269266         NaN              NaN            NaN             NaN
# 3     0.007063         NaN              NaN            NaN             NaN
# 4     0.281278         NaN              NaN            NaN             NaN
# ..         ...         ...              ...            ...             ...
# 100   0.248108         4.0              NaN            NaN             NaN
# 101   0.005614         4.0              NaN            NaN             NaN
# 102   0.018060         4.0              NaN            NaN             NaN
# 103   0.238715         1.0              1.0           16.0           256.0
# 104   0.007511         1.0              1.0           16.0           256.0
#
# [105 rows x 20 columns]

# %%
# let's drop lines where num layer is NaN

results = results[results['num_layers'].notna()]
results
# Out:
#                                     data variational  convolution
# 18        ../workfiles/light_BRCA_ds.pkl         NaN         True  \
# 19           ../workfiles/PPMI_genes.pkl         NaN         True
# 20        ../workfiles/light_BRCA_ds.pkl         VAE         True
# 21           ../workfiles/PPMI_genes.pkl         VAE         True
# 22        ../workfiles/light_BRCA_ds.pkl         NaN         True
# ..                                   ...         ...          ...
# 100       ../workfiles/light_BRCA_ds.pkl         NaN         True
# 101          ../workfiles/PPMI_genes.pkl         NaN         True
# 102  ../workfiles/PPMI_genes_PD_only.pkl         NaN         True
# 103       ../workfiles/light_BRCA_ds.pkl      VQ-VAE         True
# 104          ../workfiles/PPMI_genes.pkl      VQ-VAE         True
#
#      transformer  dropout  latent_dim  padding  kernel_size   hopkins
# 18         False      0.5          16        2            5  0.782300  \
# 19         False      0.5          16        2            5  0.818165
# 20         False      0.5          32        3            7  0.897358
# 21         False      0.5          32        3            7  0.947097
# 22         False      0.5          32        1            3  0.838968
# ..           ...      ...         ...      ...          ...       ...
# 100        False      0.1          16        2            5  0.730126
# 101        False      0.1          16        2            5  0.776597
# 102        False      0.1          16        2            5  0.795068
# 103        False      0.1         128        1            3  0.658982
# 104        False      0.1         128        1            3  0.683237
#
#           ari       nmi  silhouette        fm  homogeneity  completeness
# 18   0.168812  0.245431    0.154505  0.423880     0.263226      0.229890  \
# 19  -0.002397  0.016632    0.104400  0.377287     0.027273      0.011964
# 20   0.074810  0.093994    0.262324  0.345542     0.101391      0.087603
# 21  -0.006648  0.005323    0.336272  0.419194     0.008110      0.003962
# 22   0.246258  0.303270    0.157934  0.485458     0.321690      0.286845
# ..        ...       ...         ...       ...          ...           ...
# 100  0.155617  0.248108    0.104178  0.410244     0.267848      0.231078
# 101 -0.013216  0.005614    0.144002  0.437029     0.008369      0.004224
# 102  0.024922  0.018060    0.219111  0.526523     0.036901      0.011956
# 103  0.159659  0.238715    0.064201  0.392837     0.267033      0.215828
# 104 -0.000133  0.007511    0.057945  0.364960     0.012561      0.005357
#
#      v_measure  num_layers  commitment_cost  embedding_dim  num_embeddings
# 18    0.245431         2.0              NaN            NaN             NaN
# 19    0.016632         2.0              NaN            NaN             NaN
# 20    0.093994         5.0              NaN            NaN             NaN
# 21    0.005323         5.0              NaN            NaN             NaN
# 22    0.303270         2.0              NaN            NaN             NaN
# ..         ...         ...              ...            ...             ...
# 100   0.248108         4.0              NaN            NaN             NaN
# 101   0.005614         4.0              NaN            NaN             NaN
# 102   0.018060         4.0              NaN            NaN             NaN
# 103   0.238715         1.0              1.0           16.0           256.0
# 104   0.007511         1.0              1.0           16.0           256.0
#
# [87 rows x 20 columns]

# %%
results.columns
# Out:
# Index(['data', 'variational', 'convolution', 'transformer', 'dropout',
#        'latent_dim', 'padding', 'kernel_size', 'hopkins', 'ari', 'nmi',
#        'silhouette', 'fm', 'homogeneity', 'completeness', 'v_measure',
#        'num_layers', 'commitment_cost', 'embedding_dim', 'num_embeddings'],
#       dtype='object')

# %%
results['variational'] = results['variational'].fillna("No")
# Out:
# /var/folders/xr/0fvz4r2s4wx1hx13jlhxj2z00000gn/T/ipykernel_42424/4171622134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results['variational'] = results['variational'].fillna("No")

# %%
BRCA_df = results[results['data']=="../workfiles/light_BRCA_ds.pkl"]
PPMI_df = results[results['data']=="../workfiles/PPMI_genes.pkl"]
PPMI_genes_PD_df = results[results['data']=="../workfiles/PPMI_genes_PD_only.pkl"]

# %%
# what is our best performer ? 

#metric = "ari"
#metric = "hopkins"
metric = "silhouette"
values_of_interest = [metric, 'variational', 'dropout', 'latent_dim', 'padding', 'kernel_size','num_layers', 'commitment_cost', 'embedding_dim', 'num_embeddings']


best_BRCA = BRCA_df.sort_values(metric, ascending=False)[:1][values_of_interest]
best_PPMI = PPMI_df.sort_values(metric, ascending=False)[:1][values_of_interest]
best_PPMI_PD = PPMI_genes_PD_df.sort_values(metric, ascending=False)[:1][values_of_interest]

pd.concat([best_BRCA, best_PPMI, best_PPMI_PD])
# Out:
#     silhouette variational  dropout  latent_dim  padding  kernel_size
# 4     0.936110      VQ-VAE      0.3         128        1            3  \
# 7     0.952191      VQ-VAE      0.1          32        3            7
# 36    0.870213      VQ-VAE      0.1          32        3            7
#
#     num_layers  commitment_cost  embedding_dim  num_embeddings
# 4          1.0              0.2          128.0           128.0
# 7          2.0              0.2           64.0            64.0
# 36         2.0              0.2           64.0            64.0

# %% [markdown]
# ## All metrics overview based on dataset

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 8))

sns.kdeplot(results, x="ari", hue = "data", ax=axes[0, 0])
sns.kdeplot(results, x="hopkins", hue = "data", ax=axes[0, 1])
sns.kdeplot(results, x="silhouette", hue = "data", ax=axes[1, 0])
sns.kdeplot(results, x="v_measure", hue = "data", ax=axes[1, 1])
sns.kdeplot(results, x="fm", hue = "data", ax=axes[2, 0])
sns.kdeplot(results, x="nmi", hue = "data", ax=axes[2, 1])

# Adjust spacing between subplots (optional)
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ## Dropout impact

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 8))
hue = "dropout"

sns.kdeplot(results, x="ari", hue = hue, ax=axes[0, 0])
sns.kdeplot(results, x="hopkins", hue = hue, ax=axes[0, 1])
sns.kdeplot(results, x="silhouette", hue = hue, ax=axes[1, 0])
sns.kdeplot(results, x="v_measure", hue = hue, ax=axes[1, 1])
sns.kdeplot(results, x="fm", hue = hue, ax=axes[2, 0])
sns.kdeplot(results, x="nmi", hue = hue, ax=axes[2, 1])

# Adjust spacing between subplots (optional)
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ## latent_dim

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 8))
hue = "latent_dim"

sns.kdeplot(results, x="ari", hue = hue, ax=axes[0, 0])
sns.kdeplot(results, x="hopkins", hue = hue, ax=axes[0, 1])
sns.kdeplot(results, x="silhouette", hue = hue, ax=axes[1, 0])
sns.kdeplot(results, x="v_measure", hue = hue, ax=axes[1, 1])
sns.kdeplot(results, x="fm", hue = hue, ax=axes[2, 0])
sns.kdeplot(results, x="nmi", hue = hue, ax=axes[2, 1])

# Adjust spacing between subplots (optional)
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ## Variational ?

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 8))
hue = "variational"

sns.kdeplot(results, x="ari", hue = hue, ax=axes[0, 0])
sns.kdeplot(results, x="hopkins", hue = hue, ax=axes[0, 1])
sns.kdeplot(results, x="silhouette", hue = hue, ax=axes[1, 0])
sns.kdeplot(results, x="v_measure", hue = hue, ax=axes[1, 1])
sns.kdeplot(results, x="fm", hue = hue, ax=axes[2, 0])
sns.kdeplot(results, x="nmi", hue = hue, ax=axes[2, 1])

# Adjust spacing between subplots (optional)
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ## Kernel size

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 8))
hue = "kernel_size"

sns.kdeplot(results, x="ari", hue = hue, ax=axes[0, 0])
sns.kdeplot(results, x="hopkins", hue = hue, ax=axes[0, 1])
sns.kdeplot(results, x="silhouette", hue = hue, ax=axes[1, 0])
sns.kdeplot(results, x="v_measure", hue = hue, ax=axes[1, 1])
sns.kdeplot(results, x="fm", hue = hue, ax=axes[2, 0])
sns.kdeplot(results, x="nmi", hue = hue, ax=axes[2, 1])

# Adjust spacing between subplots (optional)
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ## Numlayers

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 8))
hue = "num_layers"

sns.kdeplot(results, x="ari", hue = hue, ax=axes[0, 0])
sns.kdeplot(results, x="hopkins", hue = hue, ax=axes[0, 1])
sns.kdeplot(results, x="silhouette", hue = hue, ax=axes[1, 0])
sns.kdeplot(results, x="v_measure", hue = hue, ax=axes[1, 1])
sns.kdeplot(results, x="fm", hue = hue, ax=axes[2, 0])
sns.kdeplot(results, x="nmi", hue = hue, ax=axes[2, 1])

# Adjust spacing between subplots (optional)
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ### Using chat gpt to do some processing...

# %%
# Reset index and merge
#PPMI_genes_PD_df
BRCA_df.reset_index(drop=True, inplace=True)
PPMI_df.reset_index(drop=True, inplace=True)
merged_df = pd.merge(BRCA_df, PPMI_df, left_index=True, right_index=True, suffixes=('_brca', '_ppmi'))
merged_df
# Out:
#                          data_brca variational_brca  convolution_brca
# 0   ../workfiles/light_BRCA_ds.pkl               No              True  \
# 1   ../workfiles/light_BRCA_ds.pkl              VAE              True
# 2   ../workfiles/light_BRCA_ds.pkl               No              True
# 3   ../workfiles/light_BRCA_ds.pkl               No              True
# 4   ../workfiles/light_BRCA_ds.pkl           VQ-VAE              True
# 5   ../workfiles/light_BRCA_ds.pkl               No              True
# 6   ../workfiles/light_BRCA_ds.pkl               No              True
# 7   ../workfiles/light_BRCA_ds.pkl           VQ-VAE              True
# 8   ../workfiles/light_BRCA_ds.pkl              VAE              True
# 9   ../workfiles/light_BRCA_ds.pkl           VQ-VAE              True
# 10  ../workfiles/light_BRCA_ds.pkl           VQ-VAE              True
# 11  ../workfiles/light_BRCA_ds.pkl               No              True
# 12  ../workfiles/light_BRCA_ds.pkl           VQ-VAE              True
# 13  ../workfiles/light_BRCA_ds.pkl              VAE              True
# 14  ../workfiles/light_BRCA_ds.pkl               No              True
# 15  ../workfiles/light_BRCA_ds.pkl           VQ-VAE              True
# 16  ../workfiles/light_BRCA_ds.pkl               No              True
# 17  ../workfiles/light_BRCA_ds.pkl           VQ-VAE              True
# 18  ../workfiles/light_BRCA_ds.pkl              VAE              True
# 19  ../workfiles/light_BRCA_ds.pkl               No              True
# 20  ../workfiles/light_BRCA_ds.pkl           VQ-VAE              True
# 21  ../workfiles/light_BRCA_ds.pkl               No              True
# 22  ../workfiles/light_BRCA_ds.pkl           VQ-VAE              True
# 23  ../workfiles/light_BRCA_ds.pkl              VAE              True
# 24  ../workfiles/light_BRCA_ds.pkl               No              True
# 25  ../workfiles/light_BRCA_ds.pkl           VQ-VAE              True
# 26  ../workfiles/light_BRCA_ds.pkl               No              True
# 27  ../workfiles/light_BRCA_ds.pkl           VQ-VAE              True
# 28  ../workfiles/light_BRCA_ds.pkl              VAE              True
# 29  ../workfiles/light_BRCA_ds.pkl               No              True
# 30  ../workfiles/light_BRCA_ds.pkl           VQ-VAE              True
#
#     transformer_brca  dropout_brca  latent_dim_brca  padding_brca
# 0              False           0.5               16             2  \
# 1              False           0.5               32             3
# 2              False           0.5               32             1
# 3              False           0.1               16             2
# 4              False           0.3              128             1
# 5              False           0.3               32             3
# 6              False           0.5               16             3
# 7              False           0.1               32             3
# 8              False           0.1              128             1
# 9              False           0.1               16             2
# 10             False           0.1              128             1
# 11             False           0.3               16             3
# 12             False           0.3               64             3
# 13             False           0.5               32             1
# 14             False           0.1               16             2
# 15             False           0.1              128             1
# 16             False           0.3               16             3
# 17             False           0.3               64             3
# 18             False           0.5               32             1
# 19             False           0.1               16             2
# 20             False           0.1              128             1
# 21             False           0.3               16             3
# 22             False           0.3               64             3
# 23             False           0.5               32             1
# 24             False           0.1               16             2
# 25             False           0.1              128             1
# 26             False           0.3               16             3
# 27             False           0.3               64             3
# 28             False           0.5               32             1
# 29             False           0.1               16             2
# 30             False           0.1              128             1
#
#     kernel_size_brca  hopkins_brca  ari_brca  ...  nmi_ppmi  silhouette_ppmi
# 0                  5      0.782300  0.168812  ...  0.016632         0.104400  \
# 1                  7      0.897358  0.074810  ...  0.005323         0.336272
# 2                  3      0.838968  0.246258  ...  0.005216         0.088340
# 3                  5      0.779493  0.164669  ...  0.004713         0.078878
# 4                  3      0.999614  0.128694  ...  0.003939         0.656327
# 5                  7      0.702720  0.208812  ...  0.007113         0.071880
# 6                  7      0.781063  0.115655  ...  0.027365         0.109464
# 7                  7      1.000000  0.145701  ...  0.004534         0.952191
# 8                  3      0.913712  0.039258  ...  0.003178         0.422602
# 9                  5      0.993015  0.056453  ...  0.006824         0.164748
# 10                 3      0.630015  0.156054  ...  0.009000         0.066440
# 11                 7      0.751145  0.143253  ...  0.007131         0.091720
# 12                 7      0.662570  0.176710  ...  0.008825         0.079732
# 13                 3      0.994785  0.047493  ...  0.002714         0.405564
# 14                 5      0.768133  0.158936  ...  0.004783         0.118958
# 15                 3      0.636826  0.148011  ...  0.012873         0.085551
# 16                 7      0.705872  0.138121  ...  0.008399         0.101689
# 17                 7      0.659496  0.167687  ...  0.008037         0.077964
# 18                 3      0.825968  0.057998  ...  0.003996         0.451806
# 19                 5      0.742705  0.136708  ...  0.007232         0.084017
# 20                 3      0.631090  0.030456  ...  0.006323         0.068796
# 21                 7      0.754720  0.148636  ...  0.026661         0.078259
# 22                 7      0.671895  0.132540  ...  0.010692         0.077134
# 23                 3      0.993363  0.014506  ...  0.003711         0.522296
# 24                 5      0.772191  0.122130  ...  0.003391         0.099326
# 25                 3      0.653578  0.169860  ...  0.007285         0.058053
# 26                 7      0.703467  0.281060  ...  0.011080         0.098597
# 27                 7      0.656760  0.127254  ...  0.015114         0.079236
# 28                 3      0.975683  0.042974  ...  0.003700         0.516980
# 29                 5      0.730126  0.155617  ...  0.005614         0.144002
# 30                 3      0.658982  0.159659  ...  0.007511         0.057945
#
#      fm_ppmi  homogeneity_ppmi  completeness_ppmi  v_measure_ppmi
# 0   0.377287          0.027273           0.011964        0.016632  \
# 1   0.419194          0.008110           0.003962        0.005323
# 2   0.383257          0.008528           0.003757        0.005216
# 3   0.407325          0.007431           0.003451        0.004713
# 4   0.385676          0.006415           0.002842        0.003939
# 5   0.389518          0.011528           0.005144        0.007113
# 6   0.364899          0.045820           0.019507        0.027365
# 7   0.400729          0.007225           0.003303        0.004534
# 8   0.454351          0.004528           0.002448        0.003178
# 9   0.381962          0.011153           0.004915        0.006824
# 10  0.366564          0.015034           0.006422        0.009000
# 11  0.371420          0.011894           0.005092        0.007131
# 12  0.365753          0.014751           0.006295        0.008825
# 13  0.417137          0.004148           0.002017        0.002714
# 14  0.421438          0.007382           0.003537        0.004783
# 15  0.381274          0.021174           0.009248        0.012873
# 16  0.394372          0.013357           0.006125        0.008399
# 17  0.364083          0.013443           0.005732        0.008037
# 18  0.446555          0.005837           0.003038        0.003996
# 19  0.394559          0.011534           0.005267        0.007232
# 20  0.364448          0.010582           0.004508        0.006323
# 21  0.386001          0.043588           0.019203        0.026661
# 22  0.373432          0.017617           0.007675        0.010692
# 23  0.405115          0.005838           0.002721        0.003711
# 24  0.428850          0.005222           0.002511        0.003391
# 25  0.366759          0.012189           0.005195        0.007285
# 26  0.424461          0.016855           0.008253        0.011080
# 27  0.366317          0.025320           0.010772        0.015114
# 28  0.426498          0.005617           0.002758        0.003700
# 29  0.437029          0.008369           0.004224        0.005614
# 30  0.364960          0.012561           0.005357        0.007511
#
#     num_layers_ppmi  commitment_cost_ppmi  embedding_dim_ppmi
# 0               2.0                   NaN                 NaN  \
# 1               5.0                   NaN                 NaN
# 2               2.0                   NaN                 NaN
# 3               4.0                   NaN                 NaN
# 4               1.0                   0.2               128.0
# 5               3.0                   NaN                 NaN
# 6               3.0                   NaN                 NaN
# 7               2.0                   0.2                64.0
# 8               4.0                   NaN                 NaN
# 9               2.0                   1.0                64.0
# 10              1.0                   1.0                16.0
# 11              3.0                   NaN                 NaN
# 12              1.0                   1.0                16.0
# 13              4.0                   NaN                 NaN
# 14              4.0                   NaN                 NaN
# 15              1.0                   1.0                16.0
# 16              3.0                   NaN                 NaN
# 17              1.0                   1.0                16.0
# 18              4.0                   NaN                 NaN
# 19              4.0                   NaN                 NaN
# 20              1.0                   1.0                16.0
# 21              3.0                   NaN                 NaN
# 22              1.0                   1.0                16.0
# 23              4.0                   NaN                 NaN
# 24              4.0                   NaN                 NaN
# 25              1.0                   1.0                16.0
# 26              3.0                   NaN                 NaN
# 27              1.0                   1.0                16.0
# 28              4.0                   NaN                 NaN
# 29              4.0                   NaN                 NaN
# 30              1.0                   1.0                16.0
#
#     num_embeddings_ppmi
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                 128.0
# 5                   NaN
# 6                   NaN
# 7                  64.0
# 8                   NaN
# 9                 512.0
# 10                256.0
# 11                  NaN
# 12                128.0
# 13                  NaN
# 14                  NaN
# 15                256.0
# 16                  NaN
# 17                128.0
# 18                  NaN
# 19                  NaN
# 20                256.0
# 21                  NaN
# 22                128.0
# 23                  NaN
# 24                  NaN
# 25                256.0
# 26                  NaN
# 27                128.0
# 28                  NaN
# 29                  NaN
# 30                256.0
#
# [31 rows x 40 columns]

# %%
# Fit regression model
X = merged_df['silhouette_brca']
y = merged_df['silhouette_ppmi']
X = sm.add_constant(X)  # Adds a constant term to the predictor
model = sm.OLS(y, X).fit()

# Plot scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(merged_df['silhouette_brca'], merged_df['silhouette_ppmi'], label='Data points')

# Plot regression line
predictions = model.predict(X)
plt.plot(merged_df['silhouette_brca'], predictions, color='red', label='Regression Line')

# Add labels and legend
plt.xlabel('silhouette for BRCA dataset')
plt.ylabel('silhouette for PPMI dataset')
plt.title('Scatter plot with Regression Line: BRCA vs PPMI')
plt.legend()
plt.grid(True)
plt.show()

# Print out the statistics
model_summary = model.summary()
print(model_summary)


p_value = model.pvalues['silhouette_brca']  # replace 'ari_brca' with the name of your predictor variable
print(f"The p-value for the predictor is: {p_value}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        silhouette_ppmi   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.707
# Method:                 Least Squares   F-statistic:                     73.29
# Date:                Mon, 13 Nov 2023   Prob (F-statistic):           1.98e-09
# Time:                        14:53:59   Log-Likelihood:                 23.116
# No. Observations:                  31   AIC:                            -42.23
# Df Residuals:                      29   BIC:                            -39.36
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0144      0.031      0.468      0.643      -0.049       0.077
# silhouette_brca     0.8984      0.105      8.561      0.000       0.684       1.113
# ==============================================================================
# Omnibus:                       28.207   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.457
# Skew:                           1.923   Prob(JB):                     3.71e-15
# Kurtosis:                       9.054   Cond. No.                         5.15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The p-value for the predictor is: 1.977899428248581e-09

# %%
# Fit regression model
X = merged_df['ari_brca']
y = merged_df['ari_ppmi']
X = sm.add_constant(X)  # Adds a constant term to the predictor
model = sm.OLS(y, X).fit()

# Plot scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(merged_df['ari_brca'], merged_df['ari_ppmi'], label='Data points')

# Plot regression line
predictions = model.predict(X)
plt.plot(merged_df['ari_brca'], predictions, color='red', label='Regression Line')

# Add labels and legend
plt.xlabel('ari for BRCA dataset')
plt.ylabel('ari for PPMI dataset')
plt.title('Scatter plot with Regression Line: BRCA vs PPMI')
plt.legend()
plt.grid(True)
plt.show()

# Print out the statistics
model_summary = model.summary()
print(model_summary)


p_value = model.pvalues['ari_brca']  # replace 'ari_brca' with the name of your predictor variable
print(f"The p-value for the predictor is: {p_value}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ari_ppmi   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.031
# Method:                 Least Squares   F-statistic:                   0.08704
# Date:                Mon, 13 Nov 2023   Prob (F-statistic):              0.770
# Time:                        14:54:40   Log-Likelihood:                 124.48
# No. Observations:                  31   AIC:                            -245.0
# Df Residuals:                      29   BIC:                            -242.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.002     -0.082      0.935      -0.004       0.004
# ari_brca      -0.0039      0.013     -0.295      0.770      -0.031       0.023
# ==============================================================================
# Omnibus:                        8.462   Durbin-Watson:                   2.191
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):                6.892
# Skew:                          -1.064   Prob(JB):                       0.0319
# Kurtosis:                       3.898   Cond. No.                         16.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The p-value for the predictor is: 0.7700816759787665

# %%
# Fit regression model
X = merged_df['hopkins_brca']
y = merged_df['hopkins_ppmi']
X = sm.add_constant(X)  # Adds a constant term to the predictor
model = sm.OLS(y, X).fit()

# Plot scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(merged_df['hopkins_brca'], merged_df['hopkins_ppmi'], label='Data points')

# Plot regression line
predictions = model.predict(X)
plt.plot(merged_df['hopkins_brca'], predictions, color='red', label='Regression Line')

# Add labels and legend
plt.xlabel('hopkins statistics for BRCA dataset')
plt.ylabel('hopkins statistics for PPMI dataset')
plt.title('Scatter plot with Regression Line: BRCA vs PPMI')
plt.legend()
plt.grid(True)
plt.show()

# Print out the statistics
model_summary = model.summary()
print(model_summary)


p_value = model.pvalues['hopkins_brca']  # replace 'ari_brca' with the name of your predictor variable
print(f"The p-value for the predictor is: {p_value}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           hopkins_ppmi   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     179.5
# Date:                Mon, 13 Nov 2023   Prob (F-statistic):           5.96e-14
# Time:                        14:56:25   Log-Likelihood:                 55.013
# No. Observations:                  31   AIC:                            -106.0
# Df Residuals:                      29   BIC:                            -103.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1677      0.048      3.465      0.002       0.069       0.267
# hopkins_brca     0.8178      0.061     13.397      0.000       0.693       0.943
# ==============================================================================
# Omnibus:                        8.167   Durbin-Watson:                   2.144
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):               14.538
# Skew:                           0.074   Prob(JB):                     0.000697
# Kurtosis:                       6.352   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The p-value for the predictor is: 5.959995252825726e-14

# %%
# Fit regression model
X = merged_df['v_measure_brca']
y = merged_df['v_measure_ppmi']

X_ = sm.add_constant(X)  # Adds a constant term to the predictor
model = sm.OLS(y, X_).fit()

# Plot scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Data points')

# Plot regression line
predictions = model.predict(X_)
plt.plot(X, predictions, color='red', label='Regression Line')

# Add labels and legend
plt.xlabel('V measure for BRCA dataset')
plt.ylabel('V measure for PPMI dataset')
plt.title('Scatter plot with Regression Line: BRCA vs PPMI')
plt.legend()
plt.grid(True)
plt.show()

# Print out the statistics
model_summary = model.summary()
print(model_summary)


p_value = model.pvalues['v_measure_brca']  # replace 'ari_brca' with the name of your predictor variable
print(f"The p-value for the predictor is: {p_value}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         v_measure_ppmi   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     1.868
# Date:                Mon, 13 Nov 2023   Prob (F-statistic):              0.182
# Time:                        15:04:26   Log-Likelihood:                 115.95
# No. Observations:                  31   AIC:                            -227.9
# Df Residuals:                      29   BIC:                            -225.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0048      0.003      1.741      0.092      -0.001       0.011
# v_measure_brca     0.0184      0.013      1.367      0.182      -0.009       0.046
# ==============================================================================
# Omnibus:                       30.074   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               58.106
# Skew:                           2.308   Prob(JB):                     2.41e-13
# Kurtosis:                       7.866   Cond. No.                         13.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The p-value for the predictor is: 0.18216625784971066

# %%
# Fit regression model
X = merged_df['fm_brca']
y = merged_df['fm_ppmi']

X_ = sm.add_constant(X)  # Adds a constant term to the predictor
model = sm.OLS(y, X_).fit()

# Plot scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Data points')

# Plot regression line
predictions = model.predict(X_)
plt.plot(X, predictions, color='red', label='Regression Line')

# Add labels and legend
plt.xlabel('FM for BRCA dataset')
plt.ylabel('FM for PPMI dataset')
plt.title('Scatter plot with Regression Line: BRCA vs PPMI')
plt.legend()
plt.grid(True)
plt.show()

# Print out the statistics
model_summary = model.summary()
print(model_summary)


p_value = model.pvalues['fm_brca']  # replace 'ari_brca' with the name of your predictor variable
print(f"The p-value for the predictor is: {p_value}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                fm_ppmi   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.8007
# Date:                Mon, 13 Nov 2023   Prob (F-statistic):              0.378
# Time:                        15:05:15   Log-Likelihood:                 68.807
# No. Observations:                  31   AIC:                            -133.6
# Df Residuals:                      29   BIC:                            -130.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4273      0.037     11.576      0.000       0.352       0.503
# fm_brca       -0.0861      0.096     -0.895      0.378      -0.283       0.111
# ==============================================================================
# Omnibus:                        3.754   Durbin-Watson:                   2.412
# Prob(Omnibus):                  0.153   Jarque-Bera (JB):                2.411
# Skew:                           0.485   Prob(JB):                        0.300
# Kurtosis:                       2.038   Cond. No.                         22.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The p-value for the predictor is: 0.37825064879064485

# %% [markdown]
# # 3 dimension analysis

# %%
# Reset index and merge
BRCA_df.reset_index(drop=True, inplace=True)
PPMI_df.reset_index(drop=True, inplace=True)
PPMI_genes_PD_df.reset_index(drop=True, inplace=True)

# Merge BRCA_df with PPMI_df first
merged_df = pd.merge(BRCA_df, PPMI_df, left_index=True, right_index=True, suffixes=('_brca', '_ppmi'))

# Now merge the resulting merged_df with PPMI_genes_PD_df
merged_df = pd.merge(merged_df, PPMI_genes_PD_df, left_index=True, right_index=True)

# If PPMI_genes_PD_df has a column that is also in BRCA_df or PPMI_df, you'll need to rename it first to avoid a collision
PPMI_genes_PD_df = PPMI_genes_PD_df.rename(columns={'ari': 'ari_ppmi_PD'})

# Merge again
merged_df = pd.merge(merged_df, PPMI_genes_PD_df, left_index=True, right_index=True, suffixes=('', '_ppmi_PD'))

# Now merged_df has the data from all three original DataFrames

# %%
# Fit regression model
X = merged_df['hopkins_brca']
y = merged_df['hopkins_ppmi']

X_ = sm.add_constant(X)  # Adds a constant term to the predictor
model = sm.OLS(y, X_).fit()

# Plot scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Data points')

# Plot regression line
predictions = model.predict(X_)
plt.plot(X, predictions, color='red', label='Regression Line')

# Add labels and legend
plt.xlabel('Hopkins for BRCA dataset')
plt.ylabel('Hopkins for PPMI dataset')
plt.title('Scatter plot with Regression Line: BRCA vs PPMI')
plt.legend()
plt.grid(True)
plt.show()

# Print out the statistics
model_summary = model.summary()
print(model_summary)


p_value = model.pvalues['hopkins_brca']  # replace 'ari_brca' with the name of your predictor variable
print(f"The p-value for the predictor is: {p_value}")




# Fit regression model
X = merged_df['hopkins_brca']
y = merged_df['hopkins_ppmi_PD']

X_ = sm.add_constant(X)  # Adds a constant term to the predictor
model = sm.OLS(y, X_).fit()

# Plot scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Data points')

# Plot regression line
predictions = model.predict(X_)
plt.plot(X, predictions, color='red', label='Regression Line')

# Add labels and legend
plt.xlabel('Hopkins for BRCA dataset')
plt.ylabel('Hopkins for PPMI PD dataset')
plt.title('Scatter plot with Regression Line: BRCA vs PPMI genetic & idiopathic PD')
plt.legend()
plt.grid(True)
plt.show()

# Print out the statistics
model_summary = model.summary()
print(model_summary)


p_value = model.pvalues['hopkins_brca']  # replace 'ari_brca' with the name of your predictor variable
print(f"The p-value for the predictor is: {p_value}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           hopkins_ppmi   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                     113.2
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           2.35e-10
# Time:                        17:44:23   Log-Likelihood:                 42.653
# No. Observations:                  25   AIC:                            -81.31
# Df Residuals:                      23   BIC:                            -78.87
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1936      0.059      3.255      0.003       0.071       0.317
# hopkins_brca     0.7857      0.074     10.637      0.000       0.633       0.939
# ==============================================================================
# Omnibus:                        6.338   Durbin-Watson:                   2.163
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                6.958
# Skew:                           0.220   Prob(JB):                       0.0308
# Kurtosis:                       5.547   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The p-value for the predictor is: 2.352851551397468e-10
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        hopkins_ppmi_PD   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     14.80
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           0.000823
# Time:                        17:44:23   Log-Likelihood:                 22.391
# No. Observations:                  25   AIC:                            -40.78
# Df Residuals:                      23   BIC:                            -38.34
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.2521      0.134      1.885      0.072      -0.025       0.529
# hopkins_brca     0.6390      0.166      3.847      0.001       0.295       0.983
# ==============================================================================
# Omnibus:                        6.011   Durbin-Watson:                   2.148
# Prob(Omnibus):                  0.050   Jarque-Bera (JB):                4.440
# Skew:                          -0.599   Prob(JB):                        0.109
# Kurtosis:                       4.682   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The p-value for the predictor is: 0.000822773583110313

# %% [markdown]
# ## Silhouette

# %%
# Fit regression model
X = merged_df['silhouette_brca']
y = merged_df['silhouette_ppmi']

X_ = sm.add_constant(X)  # Adds a constant term to the predictor
model = sm.OLS(y, X_).fit()

# Plot scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Data points')

# Plot regression line
predictions = model.predict(X_)
plt.plot(X, predictions, color='red', label='Regression Line')

# Add labels and legend
plt.xlabel('silhouette for BRCA dataset')
plt.ylabel('silhouette for PPMI dataset')
plt.title('Scatter plot with Regression Line: BRCA vs PPMI')
plt.legend()
plt.grid(True)
plt.show()

# Print out the statistics
model_summary = model.summary()
print(model_summary)


p_value = model.pvalues['silhouette_brca']  # replace 'ari_brca' with the name of your predictor variable
print(f"The p-value for the predictor is: {p_value}")




# Fit regression model
X = merged_df['silhouette_brca']
y = merged_df['silhouette_ppmi_PD']

X_ = sm.add_constant(X)  # Adds a constant term to the predictor
model = sm.OLS(y, X_).fit()

# Plot scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Data points')

# Plot regression line
predictions = model.predict(X_)
plt.plot(X, predictions, color='red', label='Regression Line')

# Add labels and legend
plt.xlabel('silhouette for BRCA dataset')
plt.ylabel('silhouette for PPMI PD dataset')
plt.title('Scatter plot with Regression Line: BRCA vs PPMI genetic & idiopathic PD')
plt.legend()
plt.grid(True)
plt.show()

# Print out the statistics
model_summary = model.summary()
print(model_summary)


p_value = model.pvalues['silhouette_brca']  # replace 'ari_brca' with the name of your predictor variable
print(f"The p-value for the predictor is: {p_value}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        silhouette_ppmi   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.669
# Method:                 Least Squares   F-statistic:                     49.41
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           3.66e-07
# Time:                        17:45:37   Log-Likelihood:                 16.144
# No. Observations:                  25   AIC:                            -28.29
# Df Residuals:                      23   BIC:                            -25.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0151      0.039      0.388      0.701      -0.065       0.096
# silhouette_brca     0.8830      0.126      7.029      0.000       0.623       1.143
# ==============================================================================
# Omnibus:                       23.950   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.230
# Skew:                           1.915   Prob(JB):                     1.84e-09
# Kurtosis:                       7.894   Cond. No.                         5.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The p-value for the predictor is: 3.663140298328813e-07
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     silhouette_ppmi_PD   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     3.536
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):             0.0728
# Time:                        17:45:37   Log-Likelihood:                 8.5584
# No. Observations:                  25   AIC:                            -13.12
# Df Residuals:                      23   BIC:                            -10.68
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.1286      0.053      2.440      0.023       0.020       0.238
# silhouette_brca     0.3200      0.170      1.880      0.073      -0.032       0.672
# ==============================================================================
# Omnibus:                       34.914   Durbin-Watson:                   1.919
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.646
# Skew:                           2.617   Prob(JB):                     4.62e-21
# Kurtosis:                      10.906   Cond. No.                         5.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The p-value for the predictor is: 0.0727795634800899

# %% [markdown]
# ## ARI

# %%
# Fit regression model
X = merged_df['ari_brca']
y = merged_df['ari_ppmi']

X_ = sm.add_constant(X)  # Adds a constant term to the predictor
model = sm.OLS(y, X_).fit()

# Plot scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Data points')

# Plot regression line
predictions = model.predict(X_)
plt.plot(X, predictions, color='red', label='Regression Line')

# Add labels and legend
plt.xlabel('ARI for BRCA dataset')
plt.ylabel('ARI for PPMI dataset')
plt.title('Scatter plot with Regression Line: BRCA vs PPMI')
plt.legend()
plt.grid(True)
plt.show()

# Print out the statistics
model_summary = model.summary()
print(model_summary)


p_value = model.pvalues['ari_brca']  # replace 'ari_brca' with the name of your predictor variable
print(f"The p-value for the predictor is: {p_value}")




# Fit regression model
X = merged_df['ari_brca']
y = merged_df['ari_ppmi_PD']

X_ = sm.add_constant(X)  # Adds a constant term to the predictor
model = sm.OLS(y, X_).fit()

# Plot scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Data points')

# Plot regression line
predictions = model.predict(X_)
plt.plot(X, predictions, color='red', label='Regression Line')

# Add labels and legend
plt.xlabel('ARI for BRCA dataset')
plt.ylabel('ARI for PPMI PD dataset')
plt.title('Scatter plot with Regression Line: BRCA vs PPMI genetic & idiopathic PD')
plt.legend()
plt.grid(True)
plt.show()

# Print out the statistics
model_summary = model.summary()
print(model_summary)


p_value = model.pvalues['ari_brca']  # replace 'ari_brca' with the name of your predictor variable
print(f"The p-value for the predictor is: {p_value}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ari_ppmi   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.040
# Method:                 Least Squares   F-statistic:                   0.08163
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):              0.778
# Time:                        17:46:32   Log-Likelihood:                 102.86
# No. Observations:                  25   AIC:                            -201.7
# Df Residuals:                      23   BIC:                            -199.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0011      0.002     -0.538      0.596      -0.005       0.003
# ari_brca       0.0042      0.015      0.286      0.778      -0.026       0.034
# ==============================================================================
# Omnibus:                        3.923   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                2.453
# Skew:                          -0.742   Prob(JB):                        0.293
# Kurtosis:                       3.388   Cond. No.                         17.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The p-value for the predictor is: 0.7776597119778189
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            ari_ppmi_PD   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.035
# Method:                 Least Squares   F-statistic:                    0.1978
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):              0.661
# Time:                        17:46:32   Log-Likelihood:                 90.311
# No. Observations:                  25   AIC:                            -176.6
# Df Residuals:                      23   BIC:                            -174.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0066      0.003      1.995      0.058      -0.000       0.013
# ari_brca      -0.0107      0.024     -0.445      0.661      -0.060       0.039
# ==============================================================================
# Omnibus:                        7.557   Durbin-Watson:                   1.924
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                5.461
# Skew:                           0.942   Prob(JB):                       0.0652
# Kurtosis:                       4.300   Cond. No.                         17.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# The p-value for the predictor is: 0.6606346097942084
