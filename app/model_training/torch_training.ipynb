# %% [markdown]
# # Most basic training pipeline

# %%
from autoencoder_optimiser.utils import experiment

# %%
data_param = '../workfiles/light_BRCA_ds.pkl'
config = {
    "dropout" : 0.5,
    "latent_dim" : 16,
    "convolution" : True,
    "num_layers" :  3,
    "kernel_size" : 7,
    "padding" : 3,
    "n_epoch" : 12
}

# %%
e = experiment.Experiment(data_param=data_param, model_param=config)
e.run()
# Out:
# /opt/homebrew/anaconda3/envs/thesis/lib/python3.9/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# input shape : 3242
# (1231, 3242)
# (1231, 1, 3242)
# train data: 1231
# Running the following configuration:
# ../workfiles/light_BRCA_ds.pkl
# {'dropout': 0.5, 'latent_dim': 16, 'convolution': True, 'num_layers': 3, 'kernel_size': 7, 'padding': 3}
# 100%|██████████| 12/12 [01:20<00:00,  6.70s/it]
# {'hopkins': 0.9644926696153104, 'ari': 0.006775748423285229, 'nmi': 0.013217422615911602, 'silhouette': 0.45833555, 'fm': 0.28367788193083304, 'homogeneity': 0.014628726240893382, 'completeness': 0.012054469890341075, 'v_measure': 0.013217422615911604}
